# %%
from huggingface_hub import login
login("hf_ndmOjTfFJfedVPGKoVmAXokhw")

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline

model_name = "google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Pipeline for medical Q&A
chatbot = pipeline("text2text-generation", model=model, tokenizer=tokenizer)

# Ask a question
question = "What are the symptoms of pneumonia?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Device set to use cpu
# Answer: sneezing

# %%
# Ask a question
question = "What are 5 symptoms of malaria?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: rash fever fever

# %%
# Ask a question
question = "What are 5 symptoms of malaria in a child under 5 years?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: rash

# %%
# Ask a question
question = "What are 5 symptoms of malaria?"
response = chatbot(question, max_length=400)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: rash fever fever

# %%
# Ask a question
question = "What are 5 symptoms of COVID-19?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: rash

# %%
# Ask a question
question = "What are the early signs of lung cancer?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: sputum oozing

# %%
# Ask a question
question = "What are the 4 early signs of throat cancer?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: sneezing

# %%
# Ask a question
question = "What are the early signs of breast cancer?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: a lump in the breast

# %%
# Ask a question
question = "What are 5 best foods to reduce on Kwashiokor?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: fried foods

# %%
# Ask a question
question = "What causes diarhoea?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: indigestion

# %%
# Ask a question
question = "What to do when you have strawberry legs?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: Eat them.

# %%
# Ask a question
question = "What to do incases of nosebleeding?"
response = chatbot(question, max_length=100)

print("Answer:", response[0]["generated_text"])
# Out:
# Answer: Take a cold shower.
